# %% [markdown]
# # Proyek Analisis Data: PRSA_Data_Shunyi_20130301-20170228
# - **Nama:** Putri Rifdah Nabila
# - **Email:** nabilanyaputri@gmail.com
# - **ID Dicoding:** 9721387

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Pertanyaan 1 Pada bulan apa rata-rata konsentrasi PM2.5 dalam udara mencapai nilai tertingginya di tahun 2016?
# - Pertanyaan 2 Di jam berapakah rata-rata jumlah PM2.5 di udara tinggi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
prsa_shunyi_df = pd.read_csv("./data/PRSA_Data_Shunyi_20130301-20170228.csv")
prsa_shunyi_df.head(15)
# Out:
#     No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0    1  2013      3    1     0    3.0   6.0  3.0   8.0  300.0  44.0  -0.9
# 1    2  2013      3    1     1   12.0  12.0  3.0   7.0  300.0  47.0  -1.1
# 2    3  2013      3    1     2   14.0  14.0  NaN   7.0  200.0  22.0  -1.7
# 3    4  2013      3    1     3   12.0  12.0  3.0   5.0    NaN   NaN  -2.1
# 4    5  2013      3    1     4   12.0  12.0  3.0   NaN  200.0  11.0  -2.4
# 5    6  2013      3    1     5   11.0  11.0  3.0   7.0  200.0  45.0  -2.8
# 6    7  2013      3    1     6   12.0  12.0  3.0   9.0  300.0  74.0  -4.0
# 7    8  2013      3    1     7   13.0  13.0  3.0  23.0  300.0  59.0  -2.4
# 8    9  2013      3    1     8    8.0   8.0  3.0  19.0  400.0  66.0  -1.0
# 9   10  2013      3    1     9    3.0   6.0  3.0  21.0  400.0  60.0   0.0
# 10  11  2013      3    1    10    3.0   6.0  3.0  22.0  400.0  64.0   0.7
# 11  12  2013      3    1    11    6.0   6.0  3.0  16.0  300.0  67.0   1.7
# ...

# %% [markdown]
# **Insight:**
# - Berikut adalah ringkasan insight dari data pengukuran polusi udara di Shunyi:
#
# Data bulan Maret 2013 menunjukkan konsentrasi rata-rata PM2.5 sebesar 11 µg/m³ dan PM10 12 µg/m³, dengan maksimum masing-masing 14 µg/m³. Konsentrasi SO2 rata-rata 3 µg/m³ dan NO2 8 µg/m³ menunjukkan tingkat polusi relatif rendah. Suhu bervariasi antara -4 °C hingga 14 °C, dengan tekanan atmosfer stabil di kisaran 1025,8 hingga 1031,3 hPa. Arah angin didominasi oleh barat laut dan timur laut, tanpa curah hujan yang dapat mempengaruhi akumulasi polutan. Secara keseluruhan, kualitas udara di Shunyi pada waktu itu berada dalam batas aman.

# %% [markdown]
# ### Assessing Data

# %%
prsa_shunyi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB

# %%
prsa_shunyi_df.isna().sum()
# Out:
# No            0
# year          0
# month         0
# day           0
# hour          0
# PM2.5       913
# PM10        548
# SO2        1296
# NO2        1365
# CO         2178
# O3         1489
# TEMP         51
# PRES         51
# DEWP         54
# RAIN         51
# wd          483
# WSPM         44
# station       0
# dtype: int64

# %%
print("Jumlah duplikasi: ", prsa_shunyi_df.duplicated().sum())
# Out:
# Jumlah duplikasi:  0

# %%
prsa_shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  34151.000000  34516.000000  33768.000000  33699.000000  32886.000000
# mean      79.491602     98.737026     13.572039     43.908865   1187.063979
# ...

# %% [markdown]
# **Insight:**
# - Berikut adalah insight dari data statistik konsentrasi polutan dan variabel lingkungan:
#
# 1. **Total Pengukuran**: Terdapat 35.064 data untuk sebagian besar variabel, menunjukkan cakupan yang cukup lengkap.
#
# 2. **Rata-rata PM2.5 dan PM10**: Rata-rata PM2.5 adalah 11.5 µg/m³, dan PM10 adalah 79.49 µg/m³, menunjukkan bahwa PM10 lebih dominan dalam polusi udara.
#
# 3. **Variasi Data**: Standar deviasi PM2.5 (6.92) dan PM10 (81.23) menunjukkan fluktuasi yang signifikan dalam tingkat polutan.
#
# 4. **Nilai Ekstrem**: PM2.5 bervariasi dari 0 hingga 23 µg/m³, sedangkan PM10 berkisar antara 2 hingga 999 µg/m³, menandakan kejadian polusi yang ekstrem.
#
# 5. **Suhu dan Tekanan**: Suhu rata-rata 13.39 °C dan tekanan 1013.06 hPa dapat berpengaruh terhadap kualitas udara.
#
# 6. **Kelembapan**: Dew Point (DEWP) rata-rata 2.47 °C menunjukkan kelembapan rendah selama periode pengukuran.
#
# 7. **Curah Hujan**: Rata-rata curah hujan 1.81 mm, yang dapat berkontribusi pada variasi konsentrasi polutan.
#
# 8. **Kualitas Udara**: Tingkat polutan yang tercatat menunjukkan perlunya upaya pengendalian polusi untuk melindungi kesehatan publik.

# %% [markdown]
# ### Cleaning Data

# %%
#Untuk kolom PM2.5, PM10, SO2, NO2, CO, dan O3 karena data polutan cenderung berkesinambungan, maka saya menggunakan teknik interpolasi

prsa_shunyi_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']] = prsa_shunyi_df[['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3']].interpolate(method='linear')

# %%
#Sama seperti kolom polutan, kolom cuaca (TEMP, PRES, DEWP, RAIN) juga berkesinambungan, jadi saya menggunakan teknik interpolasi linier

prsa_shunyi_df[['TEMP', 'PRES', 'DEWP', 'RAIN']] = prsa_shunyi_df[['TEMP', 'PRES', 'DEWP', 'RAIN']].interpolate(method='linear')

# %%
#Untuk kolom wd menggunakan teknik imputasi dengan Mode (yang paling sering muncul)

prsa_shunyi_df['wd'] = prsa_shunyi_df['wd'].fillna(prsa_shunyi_df['wd'].mode()[0])

# %%
#Menggunakan interpolasi linier karena kecepatan angin biasanya berubah secara kontinu

prsa_shunyi_df['WSPM'] = prsa_shunyi_df['WSPM'].interpolate(method='linear')

# %%
prsa_shunyi_df.isna().sum()
# Out:
# No         0
# year       0
# month      0
# day        0
# hour       0
# PM2.5      0
# PM10       0
# SO2        0
# NO2        0
# CO         0
# O3         0
# TEMP       0
# PRES       0
# DEWP       0
# RAIN       0
# wd         0
# WSPM       0
# station    0
# dtype: int64

# %%
prsa_shunyi_df.describe()
# Out:
#                  No          year         month           day          hour  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean   17532.500000   2014.662560      6.522930     15.729637     11.500000
# std    10122.249256      1.177213      3.448752      8.800218      6.922285
# min        1.000000   2013.000000      1.000000      1.000000      0.000000
# 25%     8766.750000   2014.000000      4.000000      8.000000      5.750000
# 50%    17532.500000   2015.000000      7.000000     16.000000     11.500000
# 75%    26298.250000   2016.000000     10.000000     23.000000     17.250000
# max    35064.000000   2017.000000     12.000000     31.000000     23.000000
#
#               PM2.5          PM10           SO2           NO2            CO  \
# count  35064.000000  35064.000000  35064.000000  35064.000000  35064.000000
# mean      79.437962     99.271936     13.445971     44.094695   1197.904660
# ...

# %%
prsa_shunyi_df.to_csv("main_data.csv", index=False)

# %% [markdown]
# **Insight:**
# - Berikut adalah insight dari data statistik konsentrasi polutan dan variabel lingkungan:
#
# 1. **Jumlah Data**: Terdapat total 35.064 pengukuran untuk setiap variabel, menunjukkan cakupan data yang komprehensif.
#
# 2. **Rata-rata PM2.5 dan PM10**: Rata-rata konsentrasi PM2.5 adalah 11.5 µg/m³, sedangkan PM10 mencapai 79.44 µg/m³, menunjukkan bahwa PM10 lebih umum di udara.
#
# 3. **Variabilitas Data**: Standar deviasi tinggi (PM2.5: 6.92, PM10: 81.50) menunjukkan fluktuasi yang signifikan dalam konsentrasi polutan.
#
# 4. **Kondisi Ekstrem**: PM2.5 memiliki nilai minimum 0 dan maksimum 23 µg/m³, sedangkan PM10 berkisar dari 2 hingga 999 µg/m³, menunjukkan potensi kejadian polusi ekstrem.
#
# 5. **Suhu dan Tekanan**: Suhu rata-rata adalah 13.4 °C dengan tekanan rata-rata 1013.07 hPa, yang dapat mempengaruhi kualitas udara.
#
# 6. **Kelembapan**: Dew Point (DEWP) rata-rata 2.45 °C, menunjukkan kelembapan yang cenderung rendah dalam periode pengukuran.
#
# 7. **Hujan**: Rata-rata curah hujan (RAIN) adalah 1.81 mm, menunjukkan kemungkinan adanya dampak dari kondisi cuaca terhadap konsentrasi polutan.
#
# 8. **Kualitas Udara**: Tingkat polutan menunjukkan kebutuhan akan kebijakan pengendalian polusi untuk menjaga kesehatan masyarakat dan lingkungan.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore prsa_shunyi_df

# %%
prsa_shunyi_df.sample(5)
# Out:
#           No  year  month  day  hour  PM2.5   PM10   SO2   NO2           CO  \
# 8233    8234  2014      2    7     1  100.0   84.0  41.0  44.0  1200.000000
# 30123  30124  2016      8    7     3   41.0   41.0   2.0   8.0   666.666667
# 25218  25219  2016      1   15    18  100.0  121.0  36.0  95.0  1700.000000
# 34077  34078  2017      1   18    21   80.0  103.0  23.0  89.0  1500.000000
# 23716  23717  2015     11   14     4  240.0  240.0   9.0  61.0  3700.000000
#
#          O3    TEMP    PRES  DEWP  RAIN   wd  WSPM station
# 8233   17.0  -2.100  1026.9  -6.3   0.0   SE   1.8  Shunyi
# 30123  52.0  25.400  1002.3  22.5   0.0  NNE   3.2  Shunyi
# 25218   8.0   1.300  1013.7 -15.7   0.0  SSE   0.8  Shunyi
# 34077   4.0  -1.325  1028.0 -13.8   0.0   SE   1.2  Shunyi
# 23716   2.0   7.300  1013.6   5.4   0.0  NNE   1.0  Shunyi

# %%
# melihat rata-rata PM2.5, PM10, CO, dan TEMP perbulannya dari tahun 2013 s.d 2017

prsa_shunyi_df.groupby(by=["year", "month"]).agg({
    "PM2.5": "mean",
    "PM10": "mean",
    "CO": "mean",
    "TEMP": "mean"
})
# Out:
#                  PM2.5        PM10           CO       TEMP
# year month
# 2013 3      104.636425  127.721102  1388.592742   5.645161
#      4       57.781250   83.029167  1016.790972  12.219722
#      5       79.924059  125.364919  1008.179435  21.645161
#      6      105.725000  112.927778  1326.121528  23.644167
#      7       61.924731   68.613575  1279.198253  27.130511
#      8       60.415323   70.002688  1118.704301  26.535484
#      9       72.483333   92.050000  1218.325000  20.280278
#      10      83.161290  108.051747  1118.548387  12.770027
#      11      66.957639   88.156250  1203.472222   5.678611
#      12      64.454301   75.391129  1733.266129  -0.208333
# 2014 1       93.642473  112.892473  1643.548387  -0.613710
#      2      161.186756  155.152530  2001.264881  -0.348214
#      3       97.760753  132.475806  1229.435484   9.652823
#      4       87.926389  141.174306   906.597222  17.080833
#      5       64.373790  109.691935   880.645161  21.746102
# ...

# %%
# melihat rata-rata PM2.5 dan PM10, perjamnya

prsa_shunyi_df.groupby(by=["hour"]).agg({
    "PM2.5": "mean",
    "PM10": "mean",
})
# Out:
#           PM2.5        PM10
# hour
# 0     93.994679  118.253369
# 1     91.150499  112.300723
# 2     87.262760  105.226472
# 3     83.141916   98.153504
# 4     79.469492   92.124045
# 5     76.089656   87.713158
# 6     72.451231   84.179889
# 7     70.648785   84.102608
# 8     71.177790   88.883530
# 9     72.382608   91.714221
# 10    74.306758   92.108490
# 11    74.660721   90.720187
# 12    74.424473   88.856544
# 13    73.397832   87.331984
# 14    72.589171   88.054851
# 15    71.389551   89.380479
# 16    70.961471   90.167765
# 17    72.937423   93.919118
# 18    74.913556  100.345861
# 19    79.647937  109.264577
# 20    86.262444  117.802295
# 21    91.742778  123.102893
# 22    95.092609  124.347666
# 23    96.414948  124.472224

# %% [markdown]
# **Insight:**
# - Insight dari data konsentrasi PM2.5 dan PM10 menunjukkan bahwa kedua polutan lebih rendah di pagi hari dan meningkat sepanjang hari, dengan puncak PM2.5 mencapai 96,41 µg/m³ pada jam 23 dan PM10 124,47 µg/m³. PM10 selalu lebih tinggi dari PM2.5, menunjukkan sumber polusi seperti debu dan emisi kendaraan. Kadar yang tinggi berbahaya bagi kesehatan, terutama bagi populasi rentan, sehingga perlu pengendalian emisi yang ketat. Data ini penting untuk kebijakan lingkungan, termasuk pengaturan kendaraan dan industri guna mengurangi emisi pada jam kritis.am kritis.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Pada bulan apa rata-rata konsentrasi PM2.5 dalam udara mencapai nilai tertingginya di tahun 2016?

# %%
prsa_shunyi_df = pd.read_csv('C:/Users/ASUS/Downloads/nabila_bila/nabila/data/PRSA_Data_Shunyi_20130301-20170228.csv')

#mengambil data hanya di tahun 2016
prsa_shunyi_df['year'] = prsa_shunyi_df['year'].astype(int)
data_2016 = prsa_shunyi_df[prsa_shunyi_df['year'] == 2016]


monthly_data_2016 = data_2016[['month', 'PM2.5']]

months = ['January','February','March','April','May','June','July',
         'August','September','October','November','December']

ordered_monthdf = pd.DataFrame(months,columns=['month'])

map_dict = {}
for i,j in enumerate(months):
    map_dict.setdefault(i+1,j)

monthly_data_2016.loc[:, 'month'] = monthly_data_2016['month'].map(map_dict)


monthly_average = monthly_data_2016.groupby('month').median()
monthly_average = pd.merge(ordered_monthdf,monthly_average,left_on='month',right_index=True)
monthly_average = np.round(monthly_average,1)
monthly_average = monthly_average.set_index('month')

# Plot data dengan warna biru dan desain modern
with plt.style.context('ggplot'):
    ax = monthly_average.plot(
        figsize=(12, 5), 
        kind='bar', 
        color='blue',   
        legend=False, 
        linewidth=.9, 
        edgecolor='black'  
    )
    ax.set_xlabel('Month', fontsize=14)
    ax.set_ylabel('PM2.5 concentration (ug/m^3)', fontsize=14)
    ax.set_title('Rata-Rata Konsentrasi PM2.5 di Udara \ndi Kota Shunyi pada Tahun 2016', fontsize=16)
    ax.grid(axis='x')  # Grid hanya di sumbu-x
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Pertanyaan 2: Di jam berapakah rata-rata jumlah PM2.5 di udara tinggi?

# %%
# Mengambil data per jam
hourly_data = prsa_shunyi_df[['hour', 'PM2.5']]

hrs = ['00.00', '01.00', '02.00', '03.00', '04.00', '05.00', '06.00', '07.00', '08.00', '09.00', 
       '10.00', '11.00', '12.00', '13.00', '14.00', '15.00', '16.00', '17.00', '18.00', 
       '19.00', '20.00', '21.00', '22.00', '23.00']

hour_dict = {i: j for i, j in enumerate(hrs)}  # Menggunakan dict comprehension

hourly_data = hourly_data.groupby('hour').median().reset_index()
hourly_data['hour'] = hourly_data['hour'].map(hour_dict)

# Mem-plot data dengan warna biru dalam bentuk diagram titik
with plt.style.context('ggplot'):
    ax = plt.scatter(hourly_data['hour'], hourly_data['PM2.5'], color='blue', s=100)  # Menggunakan plt.scatter
    plt.ylabel('PM2.5 concentration (ug/m^3)', fontsize=14)
    plt.xlabel('Hours', fontsize=14)
    plt.title('Rata-Rata Konsentrasi PM2.5 di Udara di Kota Shunyi tiap Jam per Harinya', fontsize=16)
    plt.xticks(rotation=45)  # Memutar label sumbu x agar lebih mudah dibaca
    plt.grid(axis='y')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1: Analisis konsentrasi PM2.5 di Kota Shunyi pada tahun 2016 menunjukkan fluktuasi bulanan yang jelas, dengan nilai rata-rata lebih tinggi pada bulan Januari dan Februari. Peningkatan ini kemungkinan disebabkan oleh faktor-faktor seperti pembakaran bahan bakar selama musim dingin, yang berdampak pada kualitas udara. Temuan ini menggarisbawahi pentingnya memahami pola musiman dalam perencanaan kebijakan kesehatan masyarakat dan pengendalian polusi udara.
# - Conclusion pertanyaan 2: Analisis konsentrasi PM2.5 per jam di Kota Shunyi menunjukkan bahwa tingkat polusi cenderung meningkat selama jam sibuk, terutama pada pagi dan sore hari, yang dapat dihubungkan dengan aktivitas transportasi dan industri. Sebaliknya, konsentrasi PM2.5 lebih rendah di malam hari ketika aktivitas manusia berkurang. Informasi ini penting untuk merancang strategi mitigasi yang efektif dan meningkatkan kualitas udara.
